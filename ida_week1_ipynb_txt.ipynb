# %% [markdown]
# <a href="https://colab.research.google.com/github/LIBY70/Data-Analysis/blob/main/ida_week1_ipynb_txt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Markdown Cell

# %% [markdown]
# Markdown Cell: 설명 작성

# %% [markdown]
# - 그림 삽입

# %% [markdown]
# ![](jupyter.png)

# %% [markdown]
# - 수식 작성

# %% [markdown]
# $y = ax + b$

# %%
# Code cell
a = 2
b = 3
a + b
# Out:
# 5

# %%
print(a + b)
# Out:
# 5
