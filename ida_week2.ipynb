# %% [markdown]
# <a href="https://colab.research.google.com/github/LIBY70/Data-Analysis/blob/main/ida_week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lab2: 파이썬 기본문법
#
# 본 실습 자료는 『배워서 바로 써먹는 데이터 분석with 파이썬』 (설진욱, 생능북스)를 참고하여 제작되었습니다.

# %% [markdown]
# ## 1. 변수와 자료형

# %% [markdown]
# - 변수 (variable) 선언

# %%
var1 = 1
var2 = 1.2
var3 = "123"
var4 = True #분리형

# %%
type(var1)
# Out:
# int

# %%
type(var2)
# Out:
# float

# %%
type(var3)
# Out:
# str

# %%
type(var4)
# Out:
# bool

# %% [markdown]
# - 변수의 형 변환 (type casting)

# %%
var1
# Out:
# 1

# %%
str(var1)
# Out:
# '1'

# %%
int("123")
# Out:
# 123

# %%
int("123")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_616/2958652502.py in <cell line: 0>()
# ----> 1 int("123a")
#
# ValueError: invalid literal for int() with base 10: '123a'

# %%
float("123")
# Out:
# 123.0

# %%
int(1.2) #내림
# Out:
# 1

# %% [markdown]
# - 연산자 (operator)

# %% [markdown]
# | 연산자 | 연산 | 의미 |
# |------|------|------|
# | +  | 덧셈 | 5 + 2 = 7 |
# | -  | 뺄셈 | 5 - 2 = 3 |
# | *  | 곱셈 | 5 * 2 = 10 |
# | /  | 나눗셈 | 5 / 2 = 2.5 |
# | // | 나눗셈의 몫 | 5 // 2 = 2 |
# | %  | 나눗셈의 나머지 | 5 % 2 = 1 |
# | ** | 거듭제곱 | 5 ** 2 = 25 |

# %%
a = 5
b = 2

# %%
a + b
# Out:
# 7

# %%
a - b
# Out:
# 3

# %%
a * b
# Out:
# 10

# %%
a / b
# Out:
# 2.5

# %%
a // b
# Out:
# 2

# %%
a % b
# Out:
# 1

# %%
a ** b
# Out:
# 25

# %%
"123" + "456"
# Out:
# '123456'

# %%
123 + "456"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_616/1862752268.py in <cell line: 0>()
# ----> 1 123 + "456"
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# (참고: 여러가지 추가 수학 함수를 제공하는 라이브러리 `math`)

# %%
import math

math.sqrt(2) #루트
# Out:
# 1.4142135623730951

# %%
math.exp(1) #e
# Out:
# 2.718281828459045

# %%
math.pi
# Out:
# 3.141592653589793

# %%
math.floor(2.4)
# Out:
# 2

# %%
math.ceil(2.4)
# Out:
# 3

# %%
round(2.7) #반올림
# Out:
# 3

# %% [markdown]
# - % 기호와 포맷 코드 (format code)

# %% [markdown]
# 포맷 코드란? 문자열 안에 변수 값을 원하는 형태로 삽입하기 위한 표시 방법

# %% [markdown]
# | 포맷 코드 | 설명|
# |------|------|
# | %s | 문자열 (string) |
# | %c | 1개의 문자 (character) |
# | %d | 정수 값 (decimal) |
# | %f | 소수점을 갖는 실수 값 (float) |

# %%
str1 = "apple"
char1 = "c"
int1 = 1
float1 = 1.0

# %%
print("string: %s" % str1)
print("character: %c" % char1)
print("decimal: %d" % int1)
print("float: %f" % float1)
# Out:
# string: apple
# character: c
# decimal: 1
# float: 1.000000

# %% [markdown]
# format() 함수

# %%
print("string: {}".format(str1)) #편하지만 오류가 안나고 실행되기 때문에 리스크 존재.
print("character: {}".format(char1))
print("decimal: {}".format(int1))
print("float: {}".format(float1))
# Out:
# string: string
# character: c
# decimal: 1
# float: 1.0

# %%
print("string: {}, float: {}".format(str1, float1))
# Out:
# string: string, float: 1.0

# %%
print(f"string: {str1}") # f = format 약자 , 제일 편함. 그냥포맷함수랑 같은 리스크 존재.
print(f"character: {char1}")
print(f"decimal: {int1}")
print(f"float: {float1}")
# Out:
# string: string
# character: c
# decimal: 1
# float: 1.0

# %%
print(f"string: {str1}, float: {float1}")
# Out:
# string: apple, float: 1.0

# %% [markdown]
# ## 2. 집합 자료형

# %% [markdown]
# 집합(iterable) 자료형: 요소 1개가 아닌 여러 개의 데이터를 처리하기 위한 자료형
#
# (iterable: '반복될 수 있는, 반복 가능한')

# %% [markdown]
# | 자료형 | 관련 함수 | 데이터 중복 가능 | 순서 있음 | 요소 개수를 반환하는 함수 | 사용 기호 |
# |------|------|------|------|------|------|
# | 리스트 | list() | ○ | ○ | len() | [ ] |
# | 튜플 | tuple() | ○ | ○ | len() | ( ) |
# | 딕셔너리 | dict() | 키 X, 값 ○ | X | len() | { } |

# %% [markdown]
# - 리스트 (list)

# %%
mylist = ["a", "b", "c", 1, 2, 3] #자료형 섞여도 상관없음.

# %% [markdown]
# | index | 0 | 1 | 2 | 3 | 4 | 5 |
# |---|---|---|---|---|---|---|
# | 값 | "a" | "b" | "c" | 1 | 2 | 3 |

# %% [markdown]
# 인덱싱 (indexing): 0부터 시작

# %%
mylist[0]
# Out:
# 'a'

# %%
mylist[4]
# Out:
# 2

# %% [markdown]
# 음수 index는 뒤에서부터의 순서를 의미

# %%
mylist[-1] #인덱스 : n-1
# Out:
# 3

# %%
mylist[-4] #인덱스 ; n-4
# Out:
# 'c'

# %% [markdown]
# 슬라이싱 (slicing): 전체 list 중 일부를 반환 (list 형태로)

# %%
mylist[1:4] #인덱스 : 1=< <4
# Out:
# ['b', 'c', 1]

# %%
mylist[2:] #인덱스 : 2~
# Out:
# ['c', 1, 2, 3]

# %%
mylist[:3] #인덱스 : <3
# Out:
# ['a', 'b', 'c']

# %% [markdown]
# 리스트 값의 추가, 삭제, 변경

# %%
mylist.append(4)
mylist
# Out:
# ['a', 'b', 'c', 1, 2, 3, 4]

# %%
mylist.pop()
mylist
# Out:
# ['a', 'b', 'c', 1, 2, 3]

# %%
mylist[1] = 4
mylist
# Out:
# ['a', 4, 'c', 1, 2, 3]

# %%
mylist.insert(1, "d")
mylist
# Out:
# ['a', 'd', 4, 'c', 1, 2, 3]

# %%
del mylist[1]
mylist
# Out:
# ['a', 4, 'c', 1, 2, 3]

# %% [markdown]
# - 튜플 (tuple): 리스트와의 비슷하지만 차이점은 **값을 변경할 수 없음**

# %%
mytuple = ("a", "b", "c", 1, 2, 3)

# %%
mytuple[1] = 4
mytuple
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_616/1639096847.py in <cell line: 0>()
# ----> 1 mytuple[1] = 4
#       2 mytuple
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# 튜플에 값을 추가하고 싶다면 변수를 재정의

# %%
mytuple = mytuple + (4, )
mytuple
# Out:
# ('a', 'b', 'c', 1, 2, 3, 4)

# %%
mytuple = mytuple[:-1]
mytuple
# Out:
# ('a', 'b', 'c', 1, 2, 3)

# %% [markdown]
# 리스트와 튜플 간 전환

# %%
list(mytuple)
# Out:
# ['a', 'b', 'c', 1, 2, 3]

# %%
tuple(mylist)
# Out:
# ('a', 4, 'c', 1, 2, 3)

# %% [markdown]
# - 딕셔너리 (dictionary)
#
# 키(key)와 값(value)이 1대1 대응 관계를 갖는 자료형
#
# 리스트나 튜플에서 자료에 접근하기 위해 사용했던 숫자 인덱스 대신 키를 사용

# %%
mydict = {"a": "apple", "b": "banana", "c": "cherry"}
mydict
# Out:
# {'a': 'apple', 'b': 'banana', 'c': 'cherry'}

# %%
mydict["a"] # 딕셔너리에 없는 키 값 가져올려하면 오류
# Out:
# 'apple'

# %%
mydict.get("a") #딕셔너리에 없는 키 값 가져올려하면 NONE 반환.
# Out:
# 'apple'

# %%
mydict["d"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_616/755089457.py in <cell line: 0>()
# ----> 1 mydict["d"]
#
# KeyError: 'd'

# %%
mydict.get("d") #NONE

# %%
mydict["g"] = "grape"
mydict
# Out:
# {'a': 'apple', 'b': 'banana', 'c': 'cherry', 'g': 'grape'}

# %%
mydict["a"] = 1
mydict
# Out:
# {'a': 1, 'b': 'banana', 'c': 'cherry', 'g': 'grape'}

# %%
mydict[1] = 123 # 변경아니고 키값 추가.
mydict
# Out:
# {'a': 1, 'b': 'banana', 'c': 'cherry', 'g': 'grape', 1: 123}

# %%
mydict.keys()
# Out:
# dict_keys(['a', 'b', 'c', 'g', 1])

# %%
mydict.values()
# Out:
# dict_values([1, 'banana', 'cherry', 'grape', 123])

# %%
mydict.items()
# Out:
# dict_items([('a', 1), ('b', 'banana'), ('c', 'cherry'), ('g', 'grape'), (1, 123)])

# %% [markdown]
# ## 3. 조건 판단문

# %% [markdown]
# 조건문에 사용되는 비교 연산자

# %% [markdown]
# | 연산자 | 연산 | 의미 |
# |------|------|------|
# | == | x == y | x와 y 값이 같은가? |
# | != | x != y | x와 y 값이 같지 않은가? |
# | >  | x > y  | x가 y 값보다 큰가? |
# | <  | x < y  | x가 y 값보다 작은가? |
# | >= | x >= y | x가 y 값 이상인가? |
# | <= | x <= y | x가 y 값 이하인가? |

# %%
x = 2
y = 3

# %%
a = x == y
a
# Out:
# False

# %% [markdown]
# - if문
#     ```
#     if 조건문:
#         실행문
#     ```
#
#     조건문이 참(True)인 경우에만 실행문을 실행

# %%
if x > y:
    print("x는 y보다 크다")

# %%
if x < y:
    print("x는 y보다 작다")
# Out:
# x는 y보다 작다

# %% [markdown]
# - if-else문
#     ```
#     if 조건문:
#         실행문1
#     else:
#         실행문2
#     ```
#
#     조건문이 참(True)인 경우에는 실행문1을, 거짓(False)인 경우에는 실행문2를 실행

# %%
if x > y:
    print("x는 y보다 크다")
else:
    print("x는 y보다 크지않다")
# Out:
# x는 y보다 크지않다

# %% [markdown]
# - if-elif-else문
#     ```
#     if 조건문1:
#         실행문1
#     elif 조건문2:
#         실행문2
#     ...
#     else:
#         실행문n
#     ```
#
#     여러 조건문을 순차적으로 적용

# %%
if x > y: #마지막 else 안써두 됨.
    print("x는 y보다 크다")
elif x < y:
    print("x는 y보다 작다")
else:
    print("x와 y는 같다")
# Out:
# x는 y보다 작다

# %% [markdown]
# ## 4. 반복문
#
# 반복문이란? 프로그램 소스 코드 내에서 특정한 부분의 코드가 반복적으로 수행될 수 있도록 하는 구문

# %% [markdown]
# - for문
#     ```
#     for 변수 in iterable객체:
#         반복실행문
#     ```
#
#     iterable : 반복가능한

# %%
for x in ["a", "b", "c"]:
    print(x)
# Out:
# a
# b
# c

# %% [markdown]
# `range()`: 일정한 범위의 정수 시퀀스를 생성하는 함수
#
# | 사용법 | 설명 | 결과 |
# |------|------|------|
# | `range(a)` | 0부터 `a`개의 정수 | 0, 1, ... `a-1` |
# | `range(a, b)` | `a`부터 `b-1`까지 정수 | `a`, `a+1`, ... `b-1` |
# | `range(a, b, c)` | `a`부터 `b-1`까지 정수를 `c`간격으로 skip | `a`, `a+c`, ... (`b-1` 이하 정수) |

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range(2, 5): #2=< <5
    print(i)
# Out:
# 2
# 3
# 4

# %%
for i in range(3, 11, 2): #3=< <11
    print(i)
# Out:
# 3
# 5
# 7
# 9

# %% [markdown]
# string도 리스트나 튜플처럼 반복문 적용 가능

# %%
for s in "abc":
    print(s)
# Out:
# a
# b
# c

# %% [markdown]
# 문자열 조작 함수
# | 항목 | 설명 |
# |------|------|
# | `.split(sep)` | 문자열을 분리하여 리스트 생성, `sep`의 기본값은 공백 |
# | `.upper()` | 문자열을 모두 대문자로 변환 |
# | `.lower()` | 문자열을 모두 소문자로 변환 |
# | `.replace(oldstr, newstr)` | 특정 문자열에서 `oldstr`을 `newstr`로 치환 |
# | `'joinstr'.join(iterable)` | 반복 가능한 객체(iterable)의 요소를 `joinstr` 문자열로 결합하여 반환 |

# %%
mystring = "Introduction to Data Analysis"
mylist = mystring.split() #()안에 있는 데이터로 문자열 구분, 없으면 띄어쓰기로 문자열 구분
mylist
# Out:
# ['Introduction', 'to', 'Data', 'Analysis']

# %%
# 홀수번째 단어는 대문자로, 짝수번째 단어는 소문자로 변경
for idx in range(len(mylist)):
    if idx % 2 == 0:
        mylist[idx] = mylist[idx].upper()
    else:
        mylist[idx] = mylist[idx].lower()
mylist
# Out:
# ['INTRODUCTION', 'to', 'DATA', 'analysis']

# %%
# join() 함수를 이용해 문자열 합치기
result = ",".join(mylist) # 리스트 사이에 , 넣고 합치기
result
# Out:
# 'Introduction,to,Data,Analysis'

# %% [markdown]
# 딕셔너리와 for문

# %%
mydict = {
    "a": 1,
    "b": 2,
    "c": 3
}

# %%
for key in mydict.keys():
    print(key)
# Out:
# a
# b
# c

# %%
for value in mydict.values():
    print(value)
# Out:
# 1
# 2
# 3

# %%
for k, v in mydict.items(): #튜플(?)의 키 한쌍으로 반복문 실행
    print(f"value for {k} is {v}")
# Out:
# value for a is 1
# value for b is 2
# value for c is 3

# %%
for k in mydict.keys():
    print(f"value for {k} is {mydict[k]}")
# Out:
# value for a is 1
# value for b is 2
# value for c is 3

# %% [markdown]
# - while문
#     ```
#     while 조건문:
#         반복실행문
#     ```

# %%
x = 10
while x > 5:
    print("x =", x)
    x = x - 1
# Out:
# x = 10
# x = 9
# x = 8
# x = 7
# x = 6

# %% [markdown]
# - 반복문과 리스트 컴프리헨션 (list comprehension = For문 사용해서 리스트,튜플 만드는 방법)

# %%
a = []
for i in range(5):
    a.append(i)
a
# Out:
# [0, 1, 2, 3, 4]

# %%
a = [i for i in range(5)]
a
# Out:
# [0, 1, 2, 3, 4]

# %%
a = list(10 * i for i in range(5))
a
# Out:
# [0, 10, 20, 30, 40]

# %%
a = tuple(i ** 2 for i in range(5))
a
# Out:
# (0, 1, 4, 9, 16)

# %% [markdown]
# ## 5. 내장 함수

# %% [markdown]
# - `sorted()`

# %%
a = [1, 7, 2, 45, 9, -10]
sorted(a)
# Out:
# [-10, 1, 2, 7, 9, 45]

# %%
sorted(a, reverse=True)
# Out:
# [45, 9, 7, 2, 1, -10]

# %% [markdown]
# - `lambda()`: 이름 없이 간단한 기능을 한 줄로 정의할 수 있는 익명 함수

# %% [markdown]
# 일반 함수

# %%
def nolambda(x, y):
    return 3 * x + 2 * y

# %%
x, y = 3, 5
nolambda(x, y)
# Out:
# 19

# %% [markdown]
# `lambda` 함수

# %%
yeslambda = lambda x, y : 3 * x + 2 * y # lambda 입력값 : 반환값

# %%
x, y = 3, 5
yeslambda(x, y)
# Out:
# 19

# %%
price_dict = {
    "apple": 100,
    "banana": 500,
    "watermelon": 300,
    "strawberry": 700,
}

# %%
sorted(price_dict)
# Out:
# ['apple', 'banana', 'strawberry', 'watermelon']

# %%
sorted(price_dict.items(), key=lambda x: x[0])
# Out:
# [('apple', 100), ('banana', 500), ('strawberry', 700), ('watermelon', 300)]

# %%
sorted(price_dict.items(), key=lambda x: x[1])
# Out:
# [('apple', 100), ('watermelon', 300), ('banana', 500), ('strawberry', 700)]

# %% [markdown]
# ## 6. 파일 입출력

# %% [markdown]
# - 파일 출력 (write)

# %%
file = open("example.txt", "w") ##w = write

file.write("Hello Python\n")
file.write("File I/O example")

file.close() # open 함수썼으면 closeclose항상 써야함.

# %%
with open("example.txt", "w") as file: # with 아래에선 쓰기로 파일을 연 상태다.
    file.write("Hello Python\n")
    file.write("File I/O example")

# %% [markdown]
# - 파일 입력 (read)

# %%
with open("example.txt", "r") as fr: # fr = file read
    content = fr.read()

# %%
content
# Out:
# 'Hello Python\nFile I/O example'

# %%
with open("example.txt", "r") as fr:
    lines = fr.readlines() # 줄바꿈 (lines 는 리스트가 된다.)

lines
# Out:
# ['Hello Python\n', 'File I/O example']

# %%
with open("nunumber.txt", "w") as fw:
  for i in range(10):
    fw.write(f"{i}\n")
    # fw.write("%d\n" %i)

# %% [markdown]
# ## + API 예시

# %%
import requests
import json
url = "http://api.open-notify.org/iss-now.json"
r = requests.get(url)

# %%
# string 형태
r.text
# Out:
# '{"iss_position": {"longitude": "3.0921", "latitude": "31.9705"}, "timestamp": 1773707702, "message": "success"}'

# %%
# 딕셔너리 형태
r.json()
# Out:
# {'iss_position': {'longitude': '3.0921', 'latitude': '31.9705'},
#  'timestamp': 1773707702,
#  'message': 'success'}

# %%
import requests
import json
import time

url = "http://api.open-notify.org/iss-now.json"

for i in range(10):
    r = requests.get(url)
    dt_dict = r.json()
    print(dt_dict["iss_position"])
    time.sleep(5)
# Out:
# {'longitude': '10.0295', 'latitude': '25.3896'}
# {'longitude': '10.7455', 'latitude': '24.6346'}
# {'longitude': '11.0558', 'latitude': '24.3030'}
# {'longitude': '11.3424', 'latitude': '23.9943'}
# {'longitude': '12.3875', 'latitude': '22.8494'}
# {'longitude': '12.6027', 'latitude': '22.6099'}
# {'longitude': '12.8386', 'latitude': '22.3460'}
# {'longitude': '13.0522', 'latitude': '22.1056'}
# {'longitude': '13.5615', 'latitude': '21.5276'}
# {'longitude': '13.7724', 'latitude': '21.2862'}

# %% [markdown]
# - 환율

# %%
import requests
import json

url = "https://v6.exchangerate-api.com/v6/ae583860ba35faf9e935824d/latest/USD"
r = requests.get(url)
dt_dict = r.json()

# %%
dt_dict
# Out:
# {'result': 'success',
#  'documentation': 'https://www.exchangerate-api.com/docs',
#  'terms_of_use': 'https://www.exchangerate-api.com/terms',
#  'time_last_update_unix': 1773705601,
#  'time_last_update_utc': 'Tue, 17 Mar 2026 00:00:01 +0000',
#  'time_next_update_unix': 1773792001,
#  'time_next_update_utc': 'Wed, 18 Mar 2026 00:00:01 +0000',
#  'base_code': 'USD',
#  'conversion_rates': {'USD': 1,
#   'AED': 3.6725,
#   'AFN': 62.9554,
#   'ALL': 83.8637,
#   'AMD': 377.6034,
#   'ANG': 1.79,
#   'AOA': 922.9185,
#   'ARS': 1452.25,
#   'AUD': 1.4169,
#   'AWG': 1.79,
#   'AZN': 1.6982,
#   'BAM': 1.7024,
#   'BBD': 2.0,
#   'BDT': 122.6398,
#   'BGN': 1.6421,
#   'BHD': 0.376,
#   'BIF': 2980.2845,
#   'BMD': 1.0,
#   'BND': 1.2787,
#   'BOB': 6.9129,
#   'BRL': 5.262,
#   'BSD': 1.0,
#   'BTN': 92.3996,
#   'BWP': 13.8033,
#   'BYN': 2.9633,
#   'BZD': 2.0,
#   'CAD': 1.3683,
#   'CDF': 2233.6851,
#   'CHF': 0.7882,
#   'CLF': 0.02322,
#   'CLP': 917.6553,
#   'CNH': 6.8933,
# ...

# %%
dt_dict["conversion_rates"]["KRW"]
# Out:
# 1491.163

# %% [markdown]
# - 기상청

# %%
import requests
import json

url = "http://apis.data.go.kr/1360000/VilageFcstInfoService_2.0/getVilageFcst"
api_key = "abcd1234"
page_num = 1 #데이터셋 페이지와 행 수
num_rows = 50
data_type = "JSON"
base_date, base_time = 20260316, 1400
nx, ny = 62, 126 #위치정보 경도위도 아님 군자동위치

query = f"?ServiceKey={api_key}&pageNo={page_num}&numOfRows={num_rows}&dataType={data_type}&base_date={base_date}&base_time={base_time}&nx={nx}&ny={ny}"

result = requests.get(url + query)

# %%
result.json()
